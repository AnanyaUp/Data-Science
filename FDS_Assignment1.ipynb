# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaUp/Data-Science/blob/main/FDS_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/assign_1.csv')
df.shape
# Out:
# (148, 6)

# %%
print(df.to_string())
# Out:
#                        Company   Age  Salary       Place Country  Gender
# 0                          TCS  20.0  5312.0     Chennai   India       0
# 1                      Infosys  30.0  5312.0      Mumbai   India       0
# 2                          TCS  35.0  2300.0    Calcutta   India       0
# 3                      Infosys  40.0  3000.0       Delhi   India       0
# 4                          TCS  23.0  4000.0      Mumbai   India       0
# 5                      Infosys  30.0  5000.0    Calcutta   India       0
# 6                          TCS  30.0  6000.0     Chennai   India       1
# 7                      Infosys  23.0  7000.0      Mumbai   India       1
# 8                          TCS  34.0  8000.0    Calcutta   India       1
# 9                          CTS  45.0  9000.0       Delhi   India       0
# 10                         CTS  23.0  5312.0      Mumbai   India       0
# 11                         CTS  34.0  1089.0    Calcutta   India       0
# ...

# %%
df
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
df.isnull()
# Out:
#      Company    Age  Salary  Place  Country  Gender
# 0      False  False    True  False    False   False
# 1      False  False    True  False    False   False
# 2      False  False   False  False    False   False
# 3      False  False   False  False    False   False
# 4      False  False   False  False    False   False
# ..       ...    ...     ...    ...      ...     ...
# 143    False  False   False  False    False   False
# 144    False  False   False  False    False   False
# 145    False  False   False  False    False   False
# 146    False  False   False  False    False   False
# 147    False  False   False  False    False   False
#
# [148 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Company     8
# Age        18
# Salary     24
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
df['Salary'].mean()
# Out:
# 5312.467741935484

# %%
df['Age'].mean()
# Out:
# 30.484615384615385

# %%
df['Salary'] = df['Salary'].fillna(value = 5312.0)
df['Age'] = df['Age'].fillna(value = 30.0)
df.bfill()
df
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0  5312.0   Chennai   India       0
# 1    Infosys  30.0  5312.0    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
df['Salary'].mean()
# Out:
# 5312.391891891892

# %%
df['Age'].mean()
# Out:
# 30.425675675675677

# %%
df['Salary'].median()
# Out:
# 5312.0

# %%
df['Salary'].mode()
# Out:
# 0    5312.0
# Name: Salary, dtype: float64

# %%
df.isnull().sum()
# Out:
# Company     8
# Age         0
# Salary      0
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
data = df.bfill()
data
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0  5312.0   Chennai   India       0
# 1    Infosys  30.0  5312.0    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Company    0
# Age        0
# Salary     0
# Place      0
# Country    0
# Gender     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Comparing
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=data['Age'])
plt.title('Box Plot of Age')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=data['Salary'])
plt.title('Box Plot of Salary')
plt.tight_layout()
plt.show()

# %%
# Handling OutLiers
def cap_outliers(df, column):
   Q1 = data[column].quantile(0.25)
   Q3 = data[column].quantile(0.75)
   IQR = Q3 - Q1
   lower_bound = Q1 - 1.5 * IQR
   upper_bound = Q3 + 1.5 * IQR
   data[column] = np.clip(data[column], lower_bound, upper_bound)

# Apply to Age
cap_outliers(data, 'Age')

# %%
# Box plots after capping outliers
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=data['Age'])
plt.title('Box Plot of Age After Handling Outliers')
plt.tight_layout()
plt.show()

# %%
# Handle Inconsistent Formatting
data['Country'] = data['Country'].str.upper()

# spaces and first letter capital
data['Company'] = data['Company'].str.strip().str.title()
data['Place'] = data['Place'].str.strip().str.title()
print(data[['Age', 'Salary']].describe())

# Remove duplicates
data.drop_duplicates(inplace=True)

# For consistency all values should be unique
print(data['Country'].unique())
print(data['Gender'].unique())
print(data['Company'].unique())
print(data['Place'].unique())
# Out:
#               Age       Salary
# count  148.000000   148.000000
# mean    30.425676  5312.391892
# std     10.396291  2354.305009
# min      0.000000  1089.000000
# 25%     23.000000  3149.250000
# 50%     31.000000  5312.000000
# 75%     36.000000  7084.000000
# max     54.000000  9876.000000
# ['INDIA']
# [0 1]
# ['Tcs' 'Infosys' 'Cts' 'Tata Consultancy Services' 'Congnizant'
#  'Infosys Pvt Lmt']
# ['Chennai' 'Mumbai' 'Calcutta' 'Delhi' 'Podicherry' 'Cochin' 'Noida'
#  'Hyderabad' 'Bhopal' 'Nagpur' 'Pune']

# %%
# Handling Noise
# Removing whitespaces
data['Company'] = data['Company'].str.strip()
data['Place'] = data['Place'].str.strip()

# %%
data.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      Tcs  20.0  5312.0   Chennai   INDIA       0
# 1  Infosys  30.0  5312.0    Mumbai   INDIA       0
# 2      Tcs  35.0  2300.0  Calcutta   INDIA       0
# 3  Infosys  40.0  3000.0     Delhi   INDIA       0
# 4      Tcs  23.0  4000.0    Mumbai   INDIA       0

# %%
# DATA EXPLORATION
print(data.describe())
print(data['Company'].value_counts())
print(data['Place'].value_counts())
print(data['Country'].value_counts())
print(data['Gender'].value_counts())
# Out:
#               Age       Salary      Gender
# count  144.000000   144.000000  144.000000
# mean    30.611111  5288.027778    0.222222
# std     10.021209  2368.373388    0.417191
# min      3.500000  1089.000000    0.000000
# 25%     23.000000  3045.000000    0.000000
# 50%     31.000000  5312.000000    0.000000
# 75%     36.000000  7084.000000    0.000000
# max     54.000000  9876.000000    1.000000
# Company
# Tcs                          54
# Infosys                      45
# Cts                          37
# Tata Consultancy Services     4
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: count, dtype: int64
# Place
# Mumbai        34
# Calcutta      32
# Noida         22
# Chennai       14
# Delhi         14
# Cochin        13
# Hyderabad      8
# Podicherry     3
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: count, dtype: int64
# Country
# INDIA    144
# Name: count, dtype: int64
# Gender
# 0    112
# 1     32
# ...

# %%
# Histograms
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(data['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(data['Salary'], bins=10, color='lightgreen', edgecolor='black')
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Correlation matrix
correlation_matrix = data[['Age', 'Salary']].corr()
print(correlation_matrix)

# Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Salary', data=data, alpha=0.6)
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
#              Age    Salary
# Age     1.000000  0.063042
# Salary  0.063042  1.000000

# %%
avg_salary_by_company = data.groupby('Company')['Salary'].mean()
print(avg_salary_by_company)
avg_salary_by_country = df.groupby('Country')['Salary'].mean()
print(avg_salary_by_country)
# Out:
# Company
# Congnizant                   2934.000000
# Cts                          4941.783784
# Infosys                      5020.533333
# Infosys Pvt Lmt              8202.000000
# Tata Consultancy Services    8644.000000
# Tcs                          5478.851852
# Name: Salary, dtype: float64
# Country
# INDIA    5288.027778
# Name: Salary, dtype: float64
